# %% [markdown]
# <a href="https://colab.research.google.com/github/abalckpie/professorahn/blob/main/%EC%86%8C%EB%85%BC%EB%AC%B8_3%EC%A0%88_%EB%B3%80%EC%88%98%EA%B8%B0%EC%88%A0%ED%86%B5%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
csv_test = pd.read_csv('/content/2022_2022년 지능정보사회 이용자 패널 조사_Data(가중치포함).csv')
df = pd.DataFrame(csv_test)
df
# Out:
#         No         wgt_a     wgt_b       id       Josagu  Josagu_gubun  Bon  \
# 0        1   9115.936286  1.249960      2_1  11010730061             2    1
# 1        2   7379.420451  1.011852      6_1  11010730061             2    1
# 2        3  11069.130680  1.517778      8_2  11010730061             2    1
# 3        4   5461.096385  0.748815      8_3  11010730061             2    1
# 4        5   2308.647665  0.316557      9_1  11010730061             2    1
# ...    ...           ...       ...      ...          ...           ...  ...
# 3965  3966   7621.395571  1.045031  17220_2  3809059200A             1    1
# 3966  3967   5825.114907  0.798729  17222_1  3809059200A             1    1
# 3967  3968   4474.663584  0.613557  17223_1  3809059200A             1    1
# 3968  3969   9239.046457  1.266841  17223_2  3809059200A             1    1
# 3969  3970   4474.663584  0.613557  17231_1  3809059200A             1    1
#
# ...

# %%
columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
df=df[['Age_group', 'Birth']]
age_group_6 = df[df['Age_group'] == 6]
age_group_6
# Out:
#       Age_group     Birth
# 0             6  19560104
# 13            6  19550802
# 14            6  19560129
# 19            6  19591127
# 20            6  19610215
# ...         ...       ...
# 3933          6  19580923
# 3935          6  19610702
# 3936          6  19570813
# 3939          6  19571003
# 3950          6  19581015
#
# [652 rows x 2 columns]

# %%
age_group_6['Year'] = age_group_6['Birth'].astype(str).str[:4]
age_group_6['Age'] = 2022 - age_group_6['Year'].astype(int)
print(age_group_6)
# Out:
#       Age_group     Birth  Year  Age
# 0             6  19560104  1956   66
# 13            6  19550802  1955   67
# 14            6  19560129  1956   66
# 19            6  19591127  1959   63
# 20            6  19610215  1961   61
# ...         ...       ...   ...  ...
# 3933          6  19580923  1958   64
# 3935          6  19610702  1961   61
# 3936          6  19570813  1957   65
# 3939          6  19571003  1957   65
# 3950          6  19581015  1958   64
#
# [652 rows x 4 columns]
# <ipython-input-12-b055ad8e646d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_group_6['Year'] = age_group_6['Birth'].astype(str).str[:4]
# <ipython-input-12-b055ad8e646d>:2: SettingWithCopyWarning:
# ...

# %%
age_group_6.columns
# Out:
# Index(['Age_group', 'Birth', 'Year', 'Age'], dtype='object')

# %%
mean_val = age_group_6['Age'].mean()
std_dev = age_group_6['Age'].std()
skewness = skew(age_group_6['Age'])
kurt = kurtosis(age_group_6['Age'])

print(f"Mean: {mean_val}")
print(f"Standard Deviation: {std_dev}")
print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurt}")
# Out:
# Mean: 63.855828220858896
# Standard Deviation: 2.5121663568617394
# Skewness: 0.3082384433429889
# Kurtosis: -0.8406456291099893

# %%
columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
df=df[['Age_group', 'DQ2_1', 'DQ6', 'DQ7']]
age_group_6 = df[df['Age_group'] == 6]
age_group_6
# Out:
#       Age_group  DQ2_1  DQ6  DQ7
# 0             6      4    4    3
# 13            6      4    8    3
# 14            6      4    8    3
# 19            6      6    6    4
# 20            6      5    6    4
# ...         ...    ...  ...  ...
# 4813          6      4    8    3
# 4814          6      4    5    5
# 4815          6      4   10    3
# 4995          6      4    3    5
# 5000          6      3    4    5
#
# [695 rows x 4 columns]

# %%
def descriptive_statistics(age_group_6):
    stats_summary = pd.DataFrame(index=['mean', 'std', 'skewness', 'kurtosis'])

    stats_summary['DQ2_1'] = [
        df['DQ2_1'].mean(),
        df['DQ2_1'].std(),
        stats.skew(df['DQ2_1']),
        stats.kurtosis(df['DQ2_1'])
    ]

    stats_summary['DQ6'] = [
        df['DQ6'].mean(),
        df['DQ6'].std(),
        stats.skew(df['DQ6']),
        stats.kurtosis(df['DQ6'])
    ]

    stats_summary['DQ7'] = [
        df['DQ7'].mean(),
        df['DQ7'].std(),
        stats.skew(df['DQ7']),
        stats.kurtosis(df['DQ7'])
    ]

    return stats_summary

# %%
stats_summary = descriptive_statistics(df)
print(stats_summary)
# Out:
#              DQ2_1       DQ6       DQ7
# mean      4.972411  6.354062  3.537114
# std       0.981935  1.805385  0.674850
# skewness -0.237713  0.122623  0.057448
# kurtosis -1.096948 -0.476580 -0.160748

# %% [markdown]
# 60대 이상 기술사용의사변수 기술통계

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# %%
df = df = pd.DataFrame(csv_test)
columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
age_group_6 = df[df['Age_group'] == 6]
age_group_6
# Out:
#         No         wgt_a     wgt_b       id       Josagu  Josagu_gubun  Bon  \
# 0        1   9115.936286  1.249960      2_1  11010730061             2    1
# 13      14  11810.788630  1.619473     50_1  11020710091             2    1
# 14      15   9115.936286  1.249960     50_2  11020710091             2    1
# 19      20  11810.788630  1.619473     61_1  11020710091             2    1
# 20      21   9115.936286  1.249960     61_2  11020710091             2    1
# ...    ...           ...       ...      ...          ...           ...  ...
# 3933  3934   7506.123704  1.029226  17127_1  38080330041             2    1
# 3935  3936   5652.233935  0.775024  17131_2  38080330041             2    1
# 3936  3937   5652.233935  0.775024  17136_1  38080330041             2    1
# 3939  3940   7506.123704  1.029226  17147_1  38080330041             2    1
# 3950  3951   5885.470466  0.807005  17183_1  3809059133A             1    1
#
# ...

# %%
age_group_6 = age_group_6[['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']]
age_group_6
# Out:
#       Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  Q1_8  Q1_9  Q1_10
# 0        3     2     1     3     2     2     3     4     3      2
# 13       3     3     2     4     4     3     2     4     3      4
# 14       3     3     2     4     4     3     2     3     3      3
# 19       3     3     2     3     4     2     2     3     2      2
# 20       3     2     3     3     4     4     3     2     4      3
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 4813     3     3     2     3     4     3     3     2     2      2
# 4814     2     2     2     2     2     2     2     3     2      3
# 4815     3     3     3     2     3     3     4     3     3      2
# 4995     4     4     3     2     3     3     4     4     3      3
# 5000     4     4     4     2     2     3     3     1     4      4
#
# [695 rows x 10 columns]

# %%
age_group_6_mean = pd.DataFrame(age_group_6)
age_group_6_mean['Mean_Q1'] = age_group_6_mean.mean(axis=1)
#age_group_6_mean = age_group_6_mean.loc[:,['Mean_Q1']]
age_group_6_mean
# Out:
#       Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  Q1_8  Q1_9  Q1_10  Mean_Q1
# 0        3     2     1     3     2     2     3     4     3      2      2.5
# 13       3     3     2     4     4     3     2     4     3      4      3.2
# 14       3     3     2     4     4     3     2     3     3      3      3.0
# 19       3     3     2     3     4     2     2     3     2      2      2.6
# 20       3     2     3     3     4     4     3     2     4      3      3.1
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...      ...
# 4813     3     3     2     3     4     3     3     2     2      2      2.7
# 4814     2     2     2     2     2     2     2     3     2      3      2.2
# 4815     3     3     3     2     3     3     4     3     3      2      2.9
# 4995     4     4     3     2     3     3     4     4     3      3      3.3
# 5000     4     4     4     2     2     3     3     1     4      4      3.1
#
# [695 rows x 11 columns]

# %%
mean_val = age_group_6_mean['Mean_Q1'].mean()
std_dev = age_group_6_mean['Mean_Q1'].std()
skewness = skew(age_group_6_mean['Mean_Q1'])
kurt = kurtosis(age_group_6_mean['Mean_Q1'])

print(f"Mean: {mean_val}")
print(f"Standard Deviation: {std_dev}")
print(f"Skewness: {skewness}")
print(f"Kurtosis: {kurt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9b824fd59f20> in <cell line: 1>()
# ----> 1 mean_val = age_group_6_mean['Mean_Q1'].mean()
#       2 std_dev = age_group_6_mean['Mean_Q1'].std()
#       3 skewness = skew(age_group_6_mean['Mean_Q1'])
#       4 kurt = kurtosis(age_group_6_mean['Mean_Q1'])
#       5
#
# NameError: name 'age_group_6_mean' is not defined
