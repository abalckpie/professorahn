# %% [markdown]
# <a href="https://colab.research.google.com/github/abalckpie/professorahn/blob/main/%EC%86%8C%EB%85%BC%EB%AC%B8_5%EC%A0%88_%EB%8B%A4%EC%A4%91%ED%9A%8C%EA%B7%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statsmodels.api as sm
import pandas as pd
from statsmodels.formula.api import ols
csv_test = pd.read_csv('/content/2022_2022년 지능정보사회 이용자 패널 조사_Data(가중치포함).csv')
df = pd.DataFrame(csv_test)
df
# Out:
#         No         wgt_a     wgt_b        id       Josagu  Josagu_gubun  Bon  \
# 0        1   9115.936286  1.249960       2_1  11010730061             2    1
# 1        2   7379.420451  1.011852       6_1  11010730061             2    1
# 2        3  11069.130680  1.517778       8_2  11010730061             2    1
# 3        4   5461.096385  0.748815       8_3  11010730061             2    1
# 4        5   2308.647665  0.316557       9_1  11010730061             2    1
# ...    ...           ...       ...       ...          ...           ...  ...
# 5373  5374   5214.785929  0.715042  204405_2  11250730521             2    2
# 5374  5375   3682.940899  0.504998  204411_1  11250730521             2    2
# 5375  5376   5807.987516  0.796380  204411_2  11250730521             2    2
# 5376  5377   2455.293933  0.336665  204417_1  11250730521             2    2
# 5377  5378   3476.523952  0.476694  204417_2  11250730521             2    2
#
# ...

# %%
columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
df=df[['Age_group', 'DQ2_1', 'DQ6', 'DQ7']]
age_group_6_1 = df[df['Age_group'] == 6]
age_group_6_1
# Out:
#       Age_group  DQ2_1  DQ6  DQ7
# 0             6      4    4    3
# 13            6      4    8    3
# 14            6      4    8    3
# 19            6      6    6    4
# 20            6      5    6    4
# ...         ...    ...  ...  ...
# 4813          6      4    8    3
# 4814          6      4    5    5
# 4815          6      4   10    3
# 4995          6      4    3    5
# 5000          6      3    4    5
#
# [695 rows x 4 columns]

# %%
df = pd.DataFrame(csv_test)
columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
age_group_6_2 = df[df['Age_group'] == 6]
age_group_6_2 = age_group_6_2[['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']]
age_group_6_2 = pd.DataFrame(age_group_6_2)
age_group_6_2['Mean_Q1'] = age_group_6_2.mean(axis=1)
age_group_6_2
# Out:
#       Q1_1  Q1_2  Q1_3  Q1_4  Q1_5  Q1_6  Q1_7  Q1_8  Q1_9  Q1_10  Mean_Q1
# 0        3     2     1     3     2     2     3     4     3      2      2.5
# 13       3     3     2     4     4     3     2     4     3      4      3.2
# 14       3     3     2     4     4     3     2     3     3      3      3.0
# 19       3     3     2     3     4     2     2     3     2      2      2.6
# 20       3     2     3     3     4     4     3     2     4      3      3.1
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...      ...
# 4813     3     3     2     3     4     3     3     2     2      2      2.7
# 4814     2     2     2     2     2     2     2     3     2      3      2.2
# 4815     3     3     3     2     3     3     4     3     3      2      2.9
# 4995     4     4     3     2     3     3     4     4     3      3      3.3
# 5000     4     4     4     2     2     3     3     1     4      4      3.1
#
# [695 rows x 11 columns]

# %%
age_group_6_3 = columns_to_check = ['Q1_1', 'Q1_2', 'Q1_3', 'Q1_4', 'Q1_5', 'Q1_6', 'Q1_7', 'Q1_8', 'Q1_9', 'Q1_10']
df = df[~df[columns_to_check].isin([9]).any(axis=1)]
df=df[['Age_group', 'Birth']]
age_group_6_3 = df[df['Age_group'] == 6]
age_group_6_3['Year'] = age_group_6_3['Birth'].astype(str).str[:4]
age_group_6_3['Age'] = 2022 - age_group_6_3['Year'].astype(int)
age_group_6_3 = age_group_6_3[['Age']]
print(age_group_6_3)
# Out:
#       Age
# 0      66
# 13     67
# 14     66
# 19     63
# 20     61
# ...   ...
# 4813   68
# 4814   60
# 4815   62
# 4995   68
# 5000   69
#
# [695 rows x 1 columns]
# <ipython-input-4-6d7a3436884b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_group_6_3['Year'] = age_group_6_3['Birth'].astype(str).str[:4]
# <ipython-input-4-6d7a3436884b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_group_6_3['Age'] = 2022 - age_group_6_3['Year'].astype(int)

# %%
age_group_6 = pd.concat([age_group_6_1, age_group_6_2, age_group_6_3], axis=1)
age_group_6 = age_group_6[['Age','DQ2_1', 'DQ6', 'DQ7', 'Mean_Q1']]
age_group_6
# Out:
#       Age  DQ2_1  DQ6  DQ7  Mean_Q1
# 0      66      4    4    3      2.5
# 13     67      4    8    3      3.2
# 14     66      4    8    3      3.0
# 19     63      6    6    4      2.6
# 20     61      5    6    4      3.1
# ...   ...    ...  ...  ...      ...
# 4813   68      4    8    3      2.7
# 4814   60      4    5    5      2.2
# 4815   62      4   10    3      2.9
# 4995   68      4    3    5      3.3
# 5000   69      3    4    5      3.1
#
# [695 rows x 5 columns]

# %% [markdown]
# 1. 다중회귀분석

# %%
X = age_group_6[['Age', 'DQ2_1', 'DQ6', 'DQ7']]
Y = age_group_6['Mean_Q1']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Mean_Q1   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     31.81
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):           2.42e-24
# Time:                        04:37:09   Log-Likelihood:                -766.88
# No. Observations:                 695   AIC:                             1544.
# Df Residuals:                     690   BIC:                             1566.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7673      0.794      3.483      0.001       1.207       4.327
# ...

# %%
X = age_group_6[['DQ6']]
Y = age_group_6['Mean_Q1']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Mean_Q1   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     63.63
# Date:                Mon, 19 Aug 2024   Prob (F-statistic):           6.21e-15
# Time:                        06:43:53   Log-Likelihood:                -795.16
# No. Observations:                 695   AIC:                             1594.
# Df Residuals:                     693   BIC:                             1603.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9147      0.092     20.887      0.000       1.735       2.095
# ...

# %% [markdown]
# 2. 공차한계, VIF 계산

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X = age_group_6[['Age', 'DQ2_1', 'DQ6', 'DQ7']]
X = sm.add_constant(X)

# %%
vif_data = pd.DataFrame()
vif_data['Variable'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data['Tolerance'] = 1 / vif_data['VIF']
print(vif_data)
# Out:
#   Variable         VIF  Tolerance
# 0    const  818.531421   0.001222
# 1      Age    1.069845   0.934715
# 2    DQ2_1    1.332596   0.750415
# 3      DQ6    1.364888   0.732661
# 4      DQ7    1.145524   0.872963
